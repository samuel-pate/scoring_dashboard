# %%
import pandas as pd
import numpy as np
import gc
import lightgbm as lgb
import pickle
from bayes_opt import BayesianOptimization
from sklearn import metrics, model_selection

# %% [markdown]
# # Récupération des données

# %%
data = pd.read_csv("data/train_resampled.csv")
cat_features = pickle.load(open("data/pickle_cat_features.pkl", "rb"))

# %% [markdown]
# # Isolation de la cible et séparation des données (train, test)

# %%
X = data.drop(columns=['TARGET','Unnamed: 0'])
y = data["TARGET"]

del data
gc.collect()
# Out:
# 20

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.2, random_state=123)

print(f"X_train : {X_train.shape}")
print(f"X_test : {X_test.shape}")
print(f"y_train : {y_train.shape}")
print(f"y_test : {y_test.shape}")

def replace_name(name):
    for c in ["[","]",",","{","}",'"',":"," "]:
        if c in name :
            name = name.replace(c,"_")
    return name
            
features = list(map(replace_name, X_train.columns))
X_train.columns = features

train_data = lgb.Dataset(data=X_train, label=y_train, free_raw_data=False)

del X, y, X_train, X_test, y_train, y_test
gc.collect()
# Out:
# X_train : (311128, 676)
# X_test : (77782, 676)
# y_train : (311128,)
# y_test : (77782,)
# 0

# %% [markdown]
# # Optimisation des paramètres

# %%
# métrique f_beta

BETA = 2

def f_beta(probas_pred, y_true):
    y_pred = np.vectorize(lambda x : 0 if x<0.5 else 1)(probas_pred)
    score = metrics.fbeta_score(y_true.get_label(), y_pred, beta=BETA)
    return "F_beta", score, True

# %%
# paramètres à optimiser

def lgb_eval(num_leaves, colsample_bytree, subsample, 
             max_depth, reg_alpha, reg_lambda, min_split_gain, min_child_weight):
    params = {'application':'binary',
              'learning_rate':0.02,
              'n_estimators':100,
              'num_iterations':4000, 
              'early_stopping_round':100, 
              'metric':'auc'}
    params["num_leaves"] = int(round(num_leaves))
    params["colsample_bytree"] = max(min(colsample_bytree, 1), 0)
    params["subsample"] = max(min(subsample, 1), 0)
    params["max_depth"] = int(round(max_depth))
    params["reg_alpha"] = max(reg_alpha, 0)
    params["reg_lambda"] = max(reg_lambda, 0)
    params["min_split_gain"] = min_split_gain
    params["min_child_weight"] = min_child_weight
    cv_result = lgb.cv(params, train_data, 
                       nfold=5, seed=123, 
                       stratified=True, 
                       verbose_eval=-1, 
                       feval=f_beta,
                       categorical_feature=cat_features)
    return max(cv_result['F_beta-mean'])

# %%
# intervalle pour chaque paramètre

lgbBO = BayesianOptimization(
    lgb_eval, 
    { 'num_leaves': (24, 45),
      'colsample_bytree': (0.1, 1),
      'subsample': (0.8, 1),
      'max_depth': (5, 8.99),
      'reg_alpha': (0.001, 1),
      'reg_lambda': (0.001, 1),
      'min_split_gain': (0.001, 0.1),
      'min_child_weight': (5, 50)}, 
    random_state=123)

# %%
lgbBO.maximize(init_points=5, n_iter=10)
# Out:
# |   iter    |  target   | colsam... | max_depth | min_ch... | min_sp... | num_le... | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------------------------------------------
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/basic.py:1554: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['CODE_GENDER', 'DAYS_EMPLOYED_ANOM', 'EMERGENCYSTATE_MODE', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'NAME_CONTRACT_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'NAME_INCOME_TYPE', 'NAME_TYPE_SUITE', 'OCCUPATION_TYPE', 'ORGANIZATION_TYPE', 'WALLSMATERIAL_MODE', 'WEEKDAY_APPR_PROCESS_START']
#   warnings.warn('categorical_feature in Dataset is overridden.\n'
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.766943 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.742372 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124464
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.755233 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.719981 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.710543 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499948 -> initscore=-0.000209
# [LightGBM] [Info] Start training from score -0.000209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  1        |  0.8916   |  0.7268   |  6.142    |  15.21    |  0.05558  |  39.11    |  0.4237   |  0.9808   |  0.937    |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.599376 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.565489 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124464
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.596283 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.563042 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.602525 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499948 -> initscore=-0.000209
# [LightGBM] [Info] Start training from score -0.000209
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# |  2        |  0.8911   |  0.5328   |  6.565    |  20.44    |  0.07318  |  33.21    |  0.06062  |  0.3986   |  0.9476   |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.576114 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.616086 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124464
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.599555 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.529287 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.576148 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499948 -> initscore=-0.000209
# [LightGBM] [Info] Start training from score -0.000209
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  3        |  0.8943   |  0.2642   |  5.7      |  28.92    |  0.05365  |  37.32    |  0.8496   |  0.7247   |  0.9222   |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.802945 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.765134 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124464
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.783050 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.728687 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.774394 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499948 -> initscore=-0.000209
# [LightGBM] [Info] Start training from score -0.000209
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# |  4        |  0.8906   |  0.7502   |  6.289    |  21.28    |  0.0236   |  30.17    |  0.6313   |  0.09301  |  0.8867   |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.602888 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.569294 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124464
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.623593 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.567003 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.645658 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499948 -> initscore=-0.000209
# [LightGBM] [Info] Start training from score -0.000209
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# |  5        |  0.8906   |  0.4878   |  6.97     |  24.16    |  0.03191  |  32.95    |  0.8935   |  0.9442   |  0.9004   |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.550956 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.614801 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124464
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.537923 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.519781 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.554447 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499948 -> initscore=-0.000209
# [LightGBM] [Info] Start training from score -0.000209
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  6        |  0.895    |  0.187    |  5.597    |  31.19    |  0.08488  |  39.49    |  0.8471   |  0.574    |  0.9261   |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.546019 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.540370 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124464
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.588666 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.533961 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.566342 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499948 -> initscore=-0.000209
# [LightGBM] [Info] Start training from score -0.000209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.762814 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.749903 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124464
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.744732 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.788102 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.723565 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499948 -> initscore=-0.000209
# [LightGBM] [Info] Start training from score -0.000209
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# |  12       |  0.8902   |  0.8231   |  7.814    |  41.66    |  0.08426  |  43.13    |  0.9136   |  0.2161   |  0.8926   |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.761558 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.800453 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124464
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.790110 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.732923 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.791226 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499948 -> initscore=-0.000209
# [LightGBM] [Info] Start training from score -0.000209
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# |  13       |  0.8865   |  0.7231   |  7.78     |  16.72    |  0.06501  |  25.53    |  0.02554  |  0.4301   |  0.9844   |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.546169 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.522926 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124464
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.543146 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.550613 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.546473 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499948 -> initscore=-0.000209
# [LightGBM] [Info] Start training from score -0.000209
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# |  14       |  0.8921   |  0.116    |  8.035    |  31.31    |  0.03571  |  39.58    |  0.1668   |  0.8368   |  0.9437   |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.616528 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124437, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.548418 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124464
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.615994 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248902, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.551498 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] Number of positive: 124438, number of negative: 124465
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.546968 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 144017
# [LightGBM] [Info] Number of data points in the train set: 248903, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499944 -> initscore=-0.000225
# [LightGBM] [Info] Start training from score -0.000225
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499948 -> initscore=-0.000209
# [LightGBM] [Info] Start training from score -0.000209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499946 -> initscore=-0.000217
# [LightGBM] [Info] Start training from score -0.000217
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  15       |  0.892    |  0.4862   |  6.185    |  30.36    |  0.07133  |  39.16    |  0.8956   |  0.7414   |  0.8284   |
# =========================================================================================================================

# %%
lgbBO.res
# Out:
# [{'target': 0.891570050294335,
#   'params': {'colsample_bytree': 0.7268222670380755,
#    'max_depth': 6.141695946452014,
#    'min_child_weight': 15.20831541038914,
#    'min_split_gain': 0.05558016213920623,
#    'num_leaves': 39.108848365496826,
#    'reg_alpha': 0.4236833536643365,
#    'reg_lambda': 0.9807834341862308,
#    'subsample': 0.9369659477169727}},
#  {'target': 0.891080188239951,
#   'params': {'colsample_bytree': 0.5328387113359249,
#    'max_depth': 6.56454889759466,
#    'min_child_weight': 20.443010726789122,
#    'min_split_gain': 0.07317592103102012,
#    'num_leaves': 33.210017138272114,
#    'reg_alpha': 0.060618218712958784,
#    'reg_lambda': 0.398646211075101,
#    'subsample': 0.9475990811464071}},
#  {'target': 0.8942913523212924,
#   'params': {'colsample_bytree': 0.26424255740815,
#    'max_depth': 5.700052507028495,
#    'min_child_weight': 28.91981182288273,
#    'min_split_gain': 0.05365093112258974,
#    'num_leaves': 37.32242012957774,
#    'reg_alpha': 0.8495823622837118,
#    'reg_lambda': 0.7247308695357746,
#    'subsample': 0.9222047021355166}},
#  {'target': 0.8906419926069209,
#   'params': {'colsample_bytree': 0.7501990443131994,
#    'max_depth': 6.288606066274181,
#    'min_child_weight': 21.280489503004134,
#    'min_split_gain': 0.023598059857016608,
#    'num_leaves': 30.167994974165417,
#    'reg_alpha': 0.6313451477306332,
#    'reg_lambda': 0.0930128350051301,
#    'subsample': 0.8867402345359057}},
#  {'target': 0.8906242790169394,
#   'params': {'colsample_bytree': 0.4877764869966794,
#    'max_depth': 6.969803539624722,
#    'min_child_weight': 24.16236306331226,
#    'min_split_gain': 0.03191386107427406,
#    'num_leaves': 32.95337744621897,
#    'reg_alpha': 0.8934957739540177,
#    'reg_lambda': 0.9442158581856758,
#    'subsample': 0.9003673351768673}},
#  {'target': 0.89504918664766,
#   'params': {'colsample_bytree': 0.18704675203879897,
#    'max_depth': 5.596525079817775,
#    'min_child_weight': 31.190087127061712,
#    'min_split_gain': 0.0848793956471949,
#    'num_leaves': 39.49169250353543,
#    'reg_alpha': 0.8470633083206642,
#    'reg_lambda': 0.5740182739981458,
#    'subsample': 0.9261485670593478}},
#  {'target': 0.8922052309218327,
#   'params': {'colsample_bytree': 0.10587128142898593,
#    'max_depth': 5.0,
#    'min_child_weight': 37.60665438850036,
#    'min_split_gain': 0.05198973168078513,
#    'num_leaves': 36.211401178812174,
#    'reg_alpha': 0.00542723591909104,
#    'reg_lambda': 0.020283836551228642,
#    'subsample': 1.0}},
#  {'target': 0.8898743672485988,
#   'params': {'colsample_bytree': 0.31644640030811577,
#    'max_depth': 5.0,
#    'min_child_weight': 28.23018696723034,
#    'min_split_gain': 0.028333548830346507,
#    'num_leaves': 44.318293177640406,
#    'reg_alpha': 0.3070299429621741,
#    'reg_lambda': 0.5223997355714634,
#    'subsample': 0.8390638177525861}},
#  {'target': 0.893507996332964,
#   'params': {'colsample_bytree': 0.2300119595613924,
#    'max_depth': 7.56736249862406,
#    'min_child_weight': 32.08617751524572,
#    'min_split_gain': 0.1,
#    'num_leaves': 37.54710026477278,
#    'reg_alpha': 1.0,
#    'reg_lambda': 1.0,
#    'subsample': 0.8283039178911095}},
#  {'target': 0.8899449656536367,
#   'params': {'colsample_bytree': 1.0,
#    'max_depth': 5.0,
#    'min_child_weight': 31.54941999398538,
#    'min_split_gain': 0.1,
#    'num_leaves': 37.655698132811004,
#    'reg_alpha': 0.001,
#    'reg_lambda': 0.001,
#    'subsample': 0.8}},
#  {'target': 0.8923365372514054,
#   'params': {'colsample_bytree': 0.5647748388866061,
#    'max_depth': 6.025136127149027,
#    'min_child_weight': 46.14974687500395,
#    'min_split_gain': 0.057493660572664175,
#    'num_leaves': 39.92431828178314,
#    'reg_alpha': 0.4171883329522058,
#    'reg_lambda': 0.4763115958944235,
#    'subsample': 0.8658176732145749}},
#  {'target': 0.890235527638693,
#   'params': {'colsample_bytree': 0.8230959910516581,
#    'max_depth': 7.813634683574005,
#    'min_child_weight': 41.66489039343293,
#    'min_split_gain': 0.08426080159959032,
#    'num_leaves': 43.12643678088421,
#    'reg_alpha': 0.9136104883694637,
#    'reg_lambda': 0.21611690711684153,
#    'subsample': 0.8925557848558852}},
#  {'target': 0.8864605141214638,
#   'params': {'colsample_bytree': 0.7231283018381296,
#    'max_depth': 7.779722848466637,
#    'min_child_weight': 16.718424548122194,
#    'min_split_gain': 0.06500864258686512,
#    'num_leaves': 25.533063073630004,
#    'reg_alpha': 0.025539930524839053,
#    'reg_lambda': 0.43008959665898633,
#    'subsample': 0.9843958995808021}},
#  {'target': 0.8921049306648694,
#   'params': {'colsample_bytree': 0.11598432428992372,
#    'max_depth': 8.034954482353449,
#    'min_child_weight': 31.312700547564926,
#    'min_split_gain': 0.03570513695795118,
#    'num_leaves': 39.58354419899385,
#    'reg_alpha': 0.1667924604651487,
#    'reg_lambda': 0.8368449205679273,
#    'subsample': 0.9437331117105937}},
#  {'target': 0.8919780555399232,
#   'params': {'colsample_bytree': 0.4862317067360036,
#    'max_depth': 6.184901194272268,
#    'min_child_weight': 30.358453643554626,
#    'min_split_gain': 0.07132938625000888,
#    'num_leaves': 39.15967809037399,
#    'reg_alpha': 0.8956481636203121,
#    'reg_lambda': 0.7414010421379,
#    'subsample': 0.828398883292522}}]

# %%
max(lgbBO.res, key=lambda x:x["target"])
# Out:
# {'target': 0.89504918664766,
#  'params': {'colsample_bytree': 0.18704675203879897,
#   'max_depth': 5.596525079817775,
#   'min_child_weight': 31.190087127061712,
#   'min_split_gain': 0.0848793956471949,
#   'num_leaves': 39.49169250353543,
#   'reg_alpha': 0.8470633083206642,
#   'reg_lambda': 0.5740182739981458,
#   'subsample': 0.9261485670593478}}
