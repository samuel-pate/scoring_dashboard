# %%
import pandas as pd
import numpy as np
import gc
import lightgbm as lgb
import pickle
from bayes_opt import BayesianOptimization
from sklearn import metrics, model_selection

# %% [markdown]
# # Récupération et préparation des données

# %%
X_train = pd.read_csv("data/X_train_resampled.csv")
y_train = pd.read_csv("data/y_train_resampled.csv")
X_test = pd.read_csv("data/X_test.csv")
y_test = pd.read_csv("data/y_test.csv")

cat_features = pickle.load(open("data/pickle_cat_features.pkl", "rb"))

# %%
X_train.drop(columns="Unnamed: 0", inplace=True)
X_test.drop(columns="SK_ID_CURR", inplace=True)
y_train.drop(columns="Unnamed: 0", inplace=True)
y_test.drop(columns="SK_ID_CURR", inplace=True)

print(f"X_train : {X_train.shape}")
print(f"X_test : {X_test.shape}")
print(f"y_train : {y_train.shape}")
print(f"y_test : {y_test.shape}")

def replace_name(name):
    for c in ["[","]",",","{","}",'"',":"," "]:
        if c in name :
            name = name.replace(c,"_")
    return name
            
features = list(map(replace_name, X_train.columns))
X_train.columns = features

train_data = lgb.Dataset(data=X_train, label=y_train, free_raw_data=False)

del X_train, X_test, y_train, y_test
gc.collect()
# Out:
# X_train : (310572, 676)
# X_test : (61502, 676)
# y_train : (310572, 1)
# y_test : (61502, 1)
# 20

# %% [markdown]
# # Optimisation des paramètres

# %%
# métrique f_beta

BETA = 2

def f_beta(probas_pred, y_true):
    y_pred = np.vectorize(lambda x : 0 if x<0.5 else 1)(probas_pred)
    score = metrics.fbeta_score(y_true.get_label(), y_pred, beta=BETA)
    return "F_beta", score, True

# %%
# paramètres à optimiser

def lgb_eval(num_leaves, colsample_bytree, subsample, 
             max_depth, reg_alpha, reg_lambda, min_split_gain, min_child_weight):
    params = {'application':'binary',
              'learning_rate':0.02,
              'n_estimators':100,
              'num_iterations':4000, 
              'early_stopping_round':100, 
              'metric':'auc'}
    params["num_leaves"] = int(round(num_leaves))
    params["colsample_bytree"] = max(min(colsample_bytree, 1), 0)
    params["subsample"] = max(min(subsample, 1), 0)
    params["max_depth"] = int(round(max_depth))
    params["reg_alpha"] = max(reg_alpha, 0)
    params["reg_lambda"] = max(reg_lambda, 0)
    params["min_split_gain"] = min_split_gain
    params["min_child_weight"] = min_child_weight
    cv_result = lgb.cv(params, train_data, 
                       nfold=5, seed=123, 
                       stratified=True, 
                       verbose_eval=-1, 
                       feval=f_beta,
                       categorical_feature=cat_features)
    return max(cv_result['F_beta-mean'])

# %%
# intervalle pour chaque paramètre

lgbBO = BayesianOptimization(
    lgb_eval, 
    { 'num_leaves': (24, 45),
      'colsample_bytree': (0.1, 1),
      'subsample': (0.8, 1),
      'max_depth': (5, 8.99),
      'reg_alpha': (0.001, 1),
      'reg_lambda': (0.001, 1),
      'min_split_gain': (0.001, 0.1),
      'min_child_weight': (5, 50)}, 
    random_state=123)

# %%
lgbBO.maximize(init_points=5, n_iter=10)
# Out:
# |   iter    |  target   | colsam... | max_depth | min_ch... | min_sp... | num_le... | reg_alpha | reg_la... | subsample |
# -------------------------------------------------------------------------------------------------------------------------
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/basic.py:1554: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['CODE_GENDER', 'DAYS_EMPLOYED_ANOM', 'EMERGENCYSTATE_MODE', 'FLAG_CONT_MOBILE', 'FLAG_DOCUMENT_10', 'FLAG_DOCUMENT_11', 'FLAG_DOCUMENT_12', 'FLAG_DOCUMENT_13', 'FLAG_DOCUMENT_14', 'FLAG_DOCUMENT_15', 'FLAG_DOCUMENT_16', 'FLAG_DOCUMENT_17', 'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_2', 'FLAG_DOCUMENT_20', 'FLAG_DOCUMENT_21', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_4', 'FLAG_DOCUMENT_5', 'FLAG_DOCUMENT_6', 'FLAG_DOCUMENT_7', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_9', 'FLAG_EMAIL', 'FLAG_EMP_PHONE', 'FLAG_MOBIL', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'FLAG_PHONE', 'FLAG_WORK_PHONE', 'FONDKAPREMONT_MODE', 'HOUSETYPE_MODE', 'NAME_CONTRACT_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'NAME_INCOME_TYPE', 'NAME_TYPE_SUITE', 'OCCUPATION_TYPE', 'ORGANIZATION_TYPE', 'WALLSMATERIAL_MODE', 'WEEKDAY_APPR_PROCESS_START']
#   warnings.warn('categorical_feature in Dataset is overridden.\n'
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124228
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.703678 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124228, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.755636 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.916164 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.695478 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.889640 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500002 -> initscore=0.000008
# [LightGBM] [Info] Start training from score 0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499998 -> initscore=-0.000008
# [LightGBM] [Info] Start training from score -0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  1        |  0.8888   |  0.7268   |  6.142    |  15.21    |  0.05558  |  39.11    |  0.4237   |  0.9808   |  0.937    |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124228
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.624743 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124228, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.603934 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.570587 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.546071 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.577849 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500002 -> initscore=0.000008
# [LightGBM] [Info] Start training from score 0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499998 -> initscore=-0.000008
# [LightGBM] [Info] Start training from score -0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# |  2        |  0.8862   |  0.5328   |  6.565    |  20.44    |  0.07318  |  33.21    |  0.06062  |  0.3986   |  0.9476   |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124228
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.528226 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124228, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.509249 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.580691 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.144270 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.581339 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500002 -> initscore=0.000008
# [LightGBM] [Info] Start training from score 0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499998 -> initscore=-0.000008
# [LightGBM] [Info] Start training from score -0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# |  3        |  0.8919   |  0.2642   |  5.7      |  28.92    |  0.05365  |  37.32    |  0.8496   |  0.7247   |  0.9222   |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124228
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.691084 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124228, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.667920 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.738667 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.780659 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.712091 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500002 -> initscore=0.000008
# [LightGBM] [Info] Start training from score 0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499998 -> initscore=-0.000008
# [LightGBM] [Info] Start training from score -0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# |  4        |  0.8863   |  0.7502   |  6.289    |  21.28    |  0.0236   |  30.17    |  0.6313   |  0.09301  |  0.8867   |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124228
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.575147 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124228, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.576646 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.599936 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.534335 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.496929 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500002 -> initscore=0.000008
# [LightGBM] [Info] Start training from score 0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499998 -> initscore=-0.000008
# [LightGBM] [Info] Start training from score -0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# |  5        |  0.8866   |  0.4878   |  6.97     |  24.16    |  0.03191  |  32.95    |  0.8935   |  0.9442   |  0.9004   |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124228
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.588344 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124228, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.548433 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.530938 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.429705 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.457195 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500002 -> initscore=0.000008
# [LightGBM] [Info] Start training from score 0.000008
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499998 -> initscore=-0.000008
# [LightGBM] [Info] Start training from score -0.000008
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124228
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.555629 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124228, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.527347 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.524856 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.455614 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.586736 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500002 -> initscore=0.000008
# [LightGBM] [Info] Start training from score 0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499998 -> initscore=-0.000008
# [LightGBM] [Info] Start training from score -0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  11       |  0.8886   |  0.5648   |  6.025    |  46.15    |  0.05749  |  39.92    |  0.4172   |  0.4763   |  0.8658   |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124228
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.732658 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124228, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.658086 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.622394 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.771324 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.798127 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500002 -> initscore=0.000008
# [LightGBM] [Info] Start training from score 0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499998 -> initscore=-0.000008
# [LightGBM] [Info] Start training from score -0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# |  12       |  0.8872   |  0.8231   |  7.814    |  41.66    |  0.08426  |  43.13    |  0.9136   |  0.2161   |  0.8926   |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124228
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.681627 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124228, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.665855 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.622033 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.687254 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.599205 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500002 -> initscore=0.000008
# [LightGBM] [Info] Start training from score 0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499998 -> initscore=-0.000008
# [LightGBM] [Info] Start training from score -0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# |  13       |  0.8819   |  0.7231   |  7.78     |  16.72    |  0.06501  |  25.53    |  0.02554  |  0.4301   |  0.9844   |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124228
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.136250 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124228, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.601214 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.529935 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.132944 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.123891 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500002 -> initscore=0.000008
# [LightGBM] [Info] Start training from score 0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499998 -> initscore=-0.000008
# [LightGBM] [Info] Start training from score -0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# |  14       |  0.8904   |  0.116    |  8.035    |  31.31    |  0.03571  |  39.58    |  0.1668   |  0.8368   |  0.9437   |
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:530: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /home/samuel/.local/lib/python3.8/site-packages/lightgbm/engine.py:535: UserWarning: Found `early_stopping_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124228
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.539760 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124228, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.573131 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248457, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.488735 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.540877 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] Number of positive: 124229, number of negative: 124229
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.633960 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 140505
# [LightGBM] [Info] Number of data points in the train set: 248458, number of used features: 622
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500002 -> initscore=0.000008
# [LightGBM] [Info] Start training from score 0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499998 -> initscore=-0.000008
# [LightGBM] [Info] Start training from score -0.000008
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# |  15       |  0.8863   |  0.5322   |  8.578    |  16.54    |  0.009321 |  41.56    |  0.7001   |  0.8949   |  0.8597   |
# =========================================================================================================================

# %%
lgbBO.res
# Out:
# [{'target': 0.8888220927862911,
#   'params': {'colsample_bytree': 0.7268222670380755,
#    'max_depth': 6.141695946452014,
#    'min_child_weight': 15.20831541038914,
#    'min_split_gain': 0.05558016213920623,
#    'num_leaves': 39.108848365496826,
#    'reg_alpha': 0.4236833536643365,
#    'reg_lambda': 0.9807834341862308,
#    'subsample': 0.9369659477169727}},
#  {'target': 0.8861931125701048,
#   'params': {'colsample_bytree': 0.5328387113359249,
#    'max_depth': 6.56454889759466,
#    'min_child_weight': 20.443010726789122,
#    'min_split_gain': 0.07317592103102012,
#    'num_leaves': 33.210017138272114,
#    'reg_alpha': 0.060618218712958784,
#    'reg_lambda': 0.398646211075101,
#    'subsample': 0.9475990811464071}},
#  {'target': 0.8918735005885263,
#   'params': {'colsample_bytree': 0.26424255740815,
#    'max_depth': 5.700052507028495,
#    'min_child_weight': 28.91981182288273,
#    'min_split_gain': 0.05365093112258974,
#    'num_leaves': 37.32242012957774,
#    'reg_alpha': 0.8495823622837118,
#    'reg_lambda': 0.7247308695357746,
#    'subsample': 0.9222047021355166}},
#  {'target': 0.8863359113050636,
#   'params': {'colsample_bytree': 0.7501990443131994,
#    'max_depth': 6.288606066274181,
#    'min_child_weight': 21.280489503004134,
#    'min_split_gain': 0.023598059857016608,
#    'num_leaves': 30.167994974165417,
#    'reg_alpha': 0.6313451477306332,
#    'reg_lambda': 0.0930128350051301,
#    'subsample': 0.8867402345359057}},
#  {'target': 0.8865672633010038,
#   'params': {'colsample_bytree': 0.4877764869966794,
#    'max_depth': 6.969803539624722,
#    'min_child_weight': 24.16236306331226,
#    'min_split_gain': 0.03191386107427406,
#    'num_leaves': 32.95337744621897,
#    'reg_alpha': 0.8934957739540177,
#    'reg_lambda': 0.9442158581856758,
#    'subsample': 0.9003673351768673}},
#  {'target': 0.8916204666302209,
#   'params': {'colsample_bytree': 0.19215059818690677,
#    'max_depth': 5.473611909097321,
#    'min_child_weight': 31.856776862974005,
#    'min_split_gain': 0.07433939193936413,
#    'num_leaves': 40.071724935673494,
#    'reg_alpha': 0.9178118559977972,
#    'reg_lambda': 0.6334168980580596,
#    'subsample': 0.9321640272254074}},
#  {'target': 0.8876988638640639,
#   'params': {'colsample_bytree': 0.1,
#    'max_depth': 5.0,
#    'min_child_weight': 34.79595217582119,
#    'min_split_gain': 0.07461546362340352,
#    'num_leaves': 34.14778795957767,
#    'reg_alpha': 0.45592830406018264,
#    'reg_lambda': 0.001,
#    'subsample': 1.0}},
#  {'target': 0.8893345154201521,
#   'params': {'colsample_bytree': 0.2633486567607306,
#    'max_depth': 5.0,
#    'min_child_weight': 27.216922336936438,
#    'min_split_gain': 0.001,
#    'num_leaves': 42.13183062397951,
#    'reg_alpha': 1.0,
#    'reg_lambda': 1.0,
#    'subsample': 0.8344452720224999}},
#  {'target': 0.8861784566935494,
#   'params': {'colsample_bytree': 1.0,
#    'max_depth': 8.99,
#    'min_child_weight': 30.432103675322836,
#    'min_split_gain': 0.1,
#    'num_leaves': 38.8630127583092,
#    'reg_alpha': 1.0,
#    'reg_lambda': 1.0,
#    'subsample': 0.8}},
#  {'target': 0.8876518243700957,
#   'params': {'colsample_bytree': 0.1,
#    'max_depth': 5.0,
#    'min_child_weight': 29.868799349096314,
#    'min_split_gain': 0.001,
#    'num_leaves': 39.01446843342688,
#    'reg_alpha': 0.471739528975516,
#    'reg_lambda': 0.001,
#    'subsample': 1.0}},
#  {'target': 0.888578691350743,
#   'params': {'colsample_bytree': 0.5647748388866061,
#    'max_depth': 6.025136127149027,
#    'min_child_weight': 46.14974687500395,
#    'min_split_gain': 0.057493660572664175,
#    'num_leaves': 39.92431828178314,
#    'reg_alpha': 0.4171883329522058,
#    'reg_lambda': 0.4763115958944235,
#    'subsample': 0.8658176732145749}},
#  {'target': 0.8871849668586252,
#   'params': {'colsample_bytree': 0.8230959910516581,
#    'max_depth': 7.813634683574005,
#    'min_child_weight': 41.66489039343293,
#    'min_split_gain': 0.08426080159959032,
#    'num_leaves': 43.12643678088421,
#    'reg_alpha': 0.9136104883694637,
#    'reg_lambda': 0.21611690711684153,
#    'subsample': 0.8925557848558852}},
#  {'target': 0.8819231129164994,
#   'params': {'colsample_bytree': 0.7231283018381296,
#    'max_depth': 7.779722848466637,
#    'min_child_weight': 16.718424548122194,
#    'min_split_gain': 0.06500864258686512,
#    'num_leaves': 25.533063073630004,
#    'reg_alpha': 0.025539930524839053,
#    'reg_lambda': 0.43008959665898633,
#    'subsample': 0.9843958995808021}},
#  {'target': 0.8904242391930518,
#   'params': {'colsample_bytree': 0.11598432428992372,
#    'max_depth': 8.034954482353449,
#    'min_child_weight': 31.312700547564926,
#    'min_split_gain': 0.03570513695795118,
#    'num_leaves': 39.58354419899385,
#    'reg_alpha': 0.1667924604651487,
#    'reg_lambda': 0.8368449205679273,
#    'subsample': 0.9437331117105937}},
#  {'target': 0.8863347832609986,
#   'params': {'colsample_bytree': 0.5321724827606208,
#    'max_depth': 8.578135711054347,
#    'min_child_weight': 16.535254640838133,
#    'min_split_gain': 0.0093212522254183,
#    'num_leaves': 41.55851709027793,
#    'reg_alpha': 0.7000740768706963,
#    'reg_lambda': 0.8949458792123216,
#    'subsample': 0.8596759772832482}}]

# %%
max(lgbBO.res, key=lambda x:x["target"])
# Out:
# {'target': 0.8918735005885263,
#  'params': {'colsample_bytree': 0.26424255740815,
#   'max_depth': 5.700052507028495,
#   'min_child_weight': 28.91981182288273,
#   'min_split_gain': 0.05365093112258974,
#   'num_leaves': 37.32242012957774,
#   'reg_alpha': 0.8495823622837118,
#   'reg_lambda': 0.7247308695357746,
#   'subsample': 0.9222047021355166}}
